# %%
#Forward and Backword Elimination Techniques

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
import pandas as pd

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
dataset=pd.read_csv(r"C:\Users\LENOVO\Downloads\diabetes.csv",encoding='latin')

# %%
dataset.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
x=dataset.iloc[:,:-1]
y=dataset["Outcome"]

# %%
x.shape
# Out:
# (768, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
#Forward Elimination technique

# %%
fs=SequentialFeatureSelector(lr,k_features=8,forward=True)
fs.fit(X_scaled,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(8, 8),
#                           scoring='accuracy')

# %%
fs.feature_names

# %%
fs.k_feature_names_
# Out:
# ('0', '1', '2', '3', '4', '5', '6', '7')

# %%
fs.k_score_
# Out:
# np.float64(0.7708853238265002)

# %%
fs=SequentialFeatureSelector(lr,k_features=7,forward=True)
fs.fit(X_scaled,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(7, 7),
#                           scoring='accuracy')

# %%
fs.feature_names

# %%
fs.k_feature_names_
# Out:
# ('1', '2', '3', '4', '5', '6', '7')

# %%
fs.k_score_
# Out:
# np.float64(0.7760886172650878)

# %%
fs=SequentialFeatureSelector(lr,k_features=6,forward=True)
fs.fit(X_scaled,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(6, 6),
#                           scoring='accuracy')

# %%
fs.feature_names

# %%
fs.k_feature_names_
# Out:
# ('1', '2', '3', '5', '6', '7')

# %%
fs.k_score_
# Out:
# np.float64(0.777361853832442)

# %%
fs=SequentialFeatureSelector(lr,k_features=5,forward=True)
fs.fit(X_scaled,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(5, 5),
#                           scoring='accuracy')

# %%
fs.feature_names

# %%
fs.k_feature_names_
# Out:
# ('1', '3', '5', '6', '7')

# %%
fs.k_score_
# Out:
# np.float64(0.7760716407775231)

# %%
# backward Techanique

# %%
fs=SequentialFeatureSelector(lr,k_features=5,forward=False)
fs.fit(X_scaled,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), forward=False,
#                           k_features=(5, 5), scoring='accuracy')

# %%
fs.feature_names

# %%
fs.k_feature_names_
# Out:
# ('1', '3', '5', '6', '7')

# %%
fs.k_score_
# Out:
# np.float64(0.7760716407775231)
