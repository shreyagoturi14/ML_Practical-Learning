# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv(r"C:\Users\LENOVO\Downloads\Housing.csv.zip")
dataset.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# [3 rows x 21 columns]

# %%
dataset.drop("date",axis=1,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.drop("price",axis=1)
y=dataset["price"]

# %%
sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x))
x
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.920908 -1.473841 -1.447464 -0.979835 -0.228321 -0.915427 -0.087173
# 1      0.637508 -0.398669  0.175607  0.533634 -0.189885  0.936506 -0.087173
# 2      0.365442 -1.473841 -1.447464 -1.426254 -0.123298 -0.915427 -0.087173
# 3     -0.727656  0.676503  1.149449 -0.130550 -0.244014 -0.915427 -0.087173
# 4     -0.912881 -0.398669 -0.149007 -0.435422 -0.169653 -0.915427 -0.087173
# ...         ...       ...       ...       ...       ...       ...       ...
# 21608 -1.500887 -0.398669  0.500221 -0.598746 -0.337424  2.788439 -0.087173
# 21609  0.702156  0.676503  0.500221  0.250539 -0.224386  0.936506 -0.087173
# 21610 -1.062751 -1.473841 -1.772078 -1.154047 -0.332137  0.936506 -0.087173
# 21611 -1.491045 -0.398669  0.500221 -0.522528 -0.307076  0.936506 -0.087173
# 21612 -1.062751 -1.473841 -1.772078 -1.154047 -0.338752  0.936506 -0.087173
#
#              7         8         9         10        11        12        13  \
# 0     -0.305759 -0.629187 -0.558836 -0.734708 -0.658681 -0.544898 -0.210128
# 1     -0.305759 -0.629187 -0.558836  0.460841  0.245141 -0.681079  4.746678
# 2     -0.305759 -0.629187 -1.409587 -1.229834 -0.658681 -1.293892 -0.210128
# 3     -0.305759  2.444294 -0.558836 -0.891699  1.397515 -0.204446 -0.210128
# 4     -0.305759 -0.629187  0.291916 -0.130895 -0.658681  0.544548 -0.210128
# ...         ...       ...       ...       ...       ...       ...       ...
# 21608 -0.305759 -0.629187  0.291916 -0.312039 -0.658681  1.293542 -0.210128
# 21609 -0.305759 -0.629187  0.291916  0.629908 -0.658681  1.463768 -0.210128
# 21610 -0.305759 -0.629187 -0.558836 -0.927928 -0.658681  1.293542 -0.210128
# 21611 -0.305759 -0.629187  0.291916 -0.227505 -0.658681  1.123316 -0.210128
# 21612 -0.305759 -0.629187 -0.558836 -0.927928 -0.658681  1.259497 -0.210128
#
#              14        15        16        17        18
# 0      1.870152 -0.352572 -0.306079 -0.943355 -0.260715
# 1      0.879568  1.161568 -0.746341 -0.432686 -0.187868
# 2     -0.933388  1.283537 -0.135655  1.070140 -0.172375
# 3      1.085160 -0.283288 -1.271816 -0.914174 -0.284522
# 4     -0.073636  0.409550  1.199335 -0.272190 -0.192849
# ...         ...       ...       ...       ...       ...
# 21608  0.468382  1.004958 -0.938069 -0.666135 -0.412381
# 21609  1.272063 -0.356180 -1.051685 -0.228419 -0.203946
# 21610  1.234683  0.247888 -0.604321 -1.410253 -0.394141
# 21611 -0.952078 -0.184414  1.028910 -0.841221 -0.420511
# 21612  1.234683  0.245723 -0.604321 -1.410253 -0.417948
#
# [21613 rows x 19 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %% [markdown]
# #LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)*100
# Out:
# 70.1245007296432

# %%
print(mean_squared_error(y_test,lr.predict(x_test)))
print(mean_absolute_error(y_test,lr.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,lr.predict(x_test))))
# Out:
# 45164797567.246574
# 127474.39227865858
# 212520.1109712833

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,lr.coef_)
plt.title("LinearRegression")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %% [markdown]
# #Lasso

# %%
la=Lasso(alpha=0.01)
la.fit(x_train,y_train)
la.score(x_test,y_test)*100
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.006e+13, tolerance: 2.259e+11
#   model = cd_fast.enet_coordinate_descent(
# 70.12450046517266

# %%
print(mean_squared_error(y_test,la.predict(x_test)))
print(mean_absolute_error(y_test,la.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,la.predict(x_test))))
# Out:
# 45164797967.06446
# 127474.39218727521
# 212520.11191194225

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,la.coef_)
plt.title("Lasso")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %% [markdown]
# #Ridge

# %%
ri=Ridge(alpha=10)
ri.fit(x_train,y_train)
ri.score(x_test,y_test)*100
# Out:
# 70.12272687754826

# %%
print(mean_squared_error(y_test,ri.predict(x_test)))
print(mean_absolute_error(y_test,ri.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,ri.predict(x_test))))
# Out:
# 45167479218.524025
# 127454.88210625126
# 212526.42004824724

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,ri.coef_)
plt.title("Ridge")
plt.xlabel("columns")
plt.ylabel("coef")
plt.show()

# %%
df=pd.DataFrame({"col_name":x.columns,"LinearRegression":lr.coef_,"Lasso":la.coef_,"Ridge":ri.coef_})

# %%
df
# Out:
#     col_name  LinearRegression          Lasso          Ridge
# 0          0      -3855.129445   -3855.120204   -3852.960922
# 1          1     -31908.774759  -31908.763291  -31841.834114
# 2          2      34339.798591   34339.732166   34320.382838
# 3          3      80733.810083  257479.676128   80684.676164
# 4          4       3337.038734    3337.001667    3338.319295
# 5          5       3792.227582    3792.225508    3810.983477
# 6          6      48620.749468   48620.741946   48599.281202
# 7          7      41219.522469   41219.522772   41219.654090
# 8          8      15866.878437   15866.867268   15884.253369
# 9          9     111325.588104  111325.613739  111201.251765
# 10        10      75341.373803  -84017.377774   75285.506221
# 11        11      26571.134680  -58598.490551   26573.703373
# 12        12     -78779.316992  -78779.298563  -78662.099254
# 13        13       8131.220724    8131.213373    8158.697525
# 14        14     -29528.950413  -29528.924955  -29463.571903
# 15        15      82500.524229   82500.510370   82465.645972
# 16        16     -27121.016305  -27120.990855  -27112.424312
# 17        17      14486.777247   14486.716568   14602.731815
# 18        18      -9271.086056   -9271.054650   -9256.559795
